# %%
import numpy as np
import pandas as pd
from scipy.sparse import dok_matrix, save_npz
import os
import json

# %%
OUTPUT_PATH = "./DDDB/DrugToDisease_DGIDB_naming.tsv"
#get the claim_name to name correspondence
DGIDB = pd.read_csv("./DGIDB/DrugToGene.tsv", sep="\t")
DDDB = pd.read_csv("./DDDB/DrugToDisease.tsv", sep="\t")

#normalize columns
DGIDB['drug_name'] = DGIDB['drug_name'].str.upper()
DGIDB['drug_claim_name'] = DGIDB['drug_claim_name'].str.upper()

DDDB['ndfrt_preferred_label'] = DDDB['ndfrt_preferred_label'].str.upper()
DDDB_drug_name_array = DDDB['ndfrt_preferred_label'].unique()
print(DDDB_drug_name_array)

DDDB.iloc[38:51]
# Out:
# ['DONEPEZIL' 'MESALAMINE' 'TESTOSTERONE' 'DIAZEPAM' 'HYDROCODONE'
#  'BACLOFEN' 'GLIMEPIRIDE' 'IBUPROFEN' 'MINOCYCLINE' 'BISOPROLOL'
#  'LEVOTHYROXINE' 'CALCIFEDIOL' 'URSODIOL' 'VENLAFAXINE' 'FLUVASTATIN'
#  'FLUVOXAMINE' 'METFORMIN' 'VINORELBINE' 'TRAMADOL' 'CETIRIZINE'
#  'IRINOTECAN' 'GEMCITABINE' 'ATORVASTATIN' 'AZELASTINE' 'FEXOFENADINE'
#  'TAMSULOSIN' 'QUETIAPINE' 'CLOPIDOGREL' 'SILDENAFIL' 'MONTELUKAST'
#  'SEVELAMER' 'ESCITALOPRAM' 'ATOMOXETINE' 'PREGABALIN' 'COLCHICINE'
#  'PHENOBARBITAL' 'ISONIAZID' 'CODEINE' 'ACETAMINOPHEN' 'NITROGLYCERIN'
#  'MORPHINE' 'ASPIRIN' 'TRIAMCINOLONE' 'ESTRADIOL' 'CAPTOPRIL'
#  'HYDROCHLOROTHIAZIDE' 'SULFAMETHOXAZOLE' 'TRIMETHOPRIM' 'DOXYCYCLINE'
#  'LEVODOPA' 'CLONAZEPAM' 'BUMETANIDE' 'FLUOROURACIL'
#  'ISOSORBIDE DINITRATE' 'FUROSEMIDE' 'METRONIDAZOLE' 'LORAZEPAM'
#  'CLONIDINE' 'PHENYTOIN' 'CHLORPROMAZINE' 'CARBAMAZEPINE' 'PREDNISONE'
#  'SPIRONOLACTONE' 'CHLORTHALIDONE' 'ALLOPURINOL' 'SULFASALAZINE'
#  'TRIAMTERENE' 'THIOTEPA' 'PYRAZINAMIDE' 'DEXAMETHASONE' 'PERPHENAZINE'
#  'HYDROCORTISONE' 'FAMOTIDINE' 'PREDNISOLONE' 'ETHINYL ESTRADIOL'
#  'LEVONORGESTREL' 'DIGOXIN' 'METHYLPREDNISOLONE' 'ALPRAZOLAM' 'GLYBURIDE'
#  'CYCLOPHOSPHAMIDE' 'HALOPERIDOL' 'CARMUSTINE' 'CISPLATIN' 'ETOPOSIDE'
#  'NIFEDIPINE' 'ESTROGENS,CONJUGATED' 'ATENOLOL' 'NORETHINDRONE' 'RIFAMPIN'
#  'VALPROIC ACID' 'FENTANYL' 'CYCLOSPORINE' 'MELPHALAN' 'AZATHIOPRINE'
#  'CHLORAMBUCIL' 'BUSULFAN' 'MERCAPTOPURINE' 'NAPROXEN' 'CEPHALEXIN'
#  'RIBAVIRIN' 'CIPROFLOXACIN' 'LISINOPRIL' 'OMEPRAZOLE' 'CARBOPLATIN'
#  'LOVASTATIN' 'CLOZAPINE' 'ZIDOVUDINE' 'GOSERELIN ACETATE' 'RAMIPRIL'
#  'ATROPINE' 'AMILORIDE' 'AMIODARONE' 'AMITRIPTYLINE' 'BUPROPION'
#  'BUSPIRONE' 'CLOMIPRAMINE' 'COLESTIPOL' 'CYCLOBENZAPRINE' 'DAUNORUBICIN'
#  'DESIPRAMINE' 'DICLOFENAC' 'DILTIAZEM' 'DIPHENHYDRAMINE' 'DIPHENOXYLATE'
#  'DOCUSATE' 'DOXORUBICIN' 'ENALAPRIL' 'ETHAMBUTOL' 'FLUOXETINE'
#  'HYDRALAZINE' 'HYDROXYCHLOROQUINE' 'IMIPRAMINE' 'IPRATROPIUM' 'LABETALOL'
#  'LEUCOVORIN' 'LEUPROLIDE' 'LITHIUM' 'LOPERAMIDE' 'MECLIZINE'
#  'MEDROXYPROGESTERONE' 'METHADONE' 'METHAMPHETAMINE' 'METHOTREXATE'
#  'METHYLPHENIDATE' 'METOPROLOL' 'MOMETASONE' 'NALTREXONE' 'NORTRIPTYLINE'
#  'ONDANSETRON' 'OXYBUTYNIN' 'OXYCODONE' 'PROPRANOLOL' 'RANITIDINE'
#  'TAMOXIFEN' 'TERAZOSIN' 'TERBUTALINE' 'TRAZODONE' 'VANCOMYCIN'
#  'VERAPAMIL' 'VINBLASTINE' 'VINCRISTINE' 'WARFARIN'
#  'CHLORIDE (AS POTASSIUM)' 'CLARITHROMYCIN' 'FELODIPINE' 'FINASTERIDE'
#  'FLUTICASONE PROPIONATE' 'ISOSORBIDE MONONITRATE' 'SIMVASTATIN'
#  'FLUDARABINE' 'PAMIDRONATE' 'PRAVASTATIN' 'SERTRALINE' 'NORGESTIMATE'
#  'LORATADINE' 'PACLITAXEL' 'AMLODIPINE' 'PAROXETINE' 'BENAZEPRIL'
#  'ENOXAPARIN' 'GABAPENTIN' 'RISPERIDONE' 'TORSEMIDE' 'BUDESONIDE'
#  'LAMOTRIGINE' 'LOSARTAN' 'MYCOPHENOLATE MOFETIL' 'LANSOPRAZOLE'
#  'ALENDRONATE' 'LAMIVUDINE' 'ANASTROZOLE' 'BICALUTAMIDE' 'DOCETAXEL'
#  'MIRTAZAPINE' 'VALSARTAN' 'OLANZAPINE' 'INSULIN,LISPRO,HUMAN/RDNA'
#  'CARVEDILOL' 'LETROZOLE' 'SUMATRIPTAN' 'IRBESARTAN' 'FENOFIBRATE'
#  'CAPECITABINE' 'RITUXIMAB' 'INFLIXIMAB' 'CITALOPRAM' 'LEFLUNOMIDE'
#  'EFAVIRENZ' 'THALIDOMIDE' 'ETANERCEPT' 'CELECOXIB' 'CANDESARTAN'
#  'ROSIGLITAZONE' 'PIOGLITAZONE' 'RABEPRAZOLE' 'PERINDOPRIL' 'EPIRUBICIN'
#  'LEVETIRACETAM' 'MELOXICAM' 'PANTOPRAZOLE' 'INSULIN,GLARGINE,HUMAN/RDNA'
#  'LOPINAVIR' 'ZIPRASIDONE' 'IMATINIB' 'ESOMEPRAZOLE' 'FORMOTEROL'
#  'ZOLEDRONIC ACID' 'TENOFOVIR' 'DESLORATADINE' 'OXALIPLATIN'
#  'PEGINTERFERON ALFA-2A' 'EZETIMIBE' 'ARIPIPRAZOLE' 'ADALIMUMAB'
#  'DUTASTERIDE' 'GEFITINIB' 'BORTEZOMIB' 'INSULIN,ASPART PROTAMINE'
#  'EMTRICITABINE' 'ROSUVASTATIN' 'TADALAFIL' 'PEMETREXED' 'CETUXIMAB'
#  'BEVACIZUMAB' 'RIFAXIMIN' 'ACAMPROSATE' 'DULOXETINE' 'NATALIZUMAB'
#  'ERLOTINIB' 'OMEGA-3-ACID ETHYL ESTERS 1000MG CAP,ORAL' 'SUNITINIB'
#  'INSULIN,DETEMIR,HUMAN' 'SITAGLIPTIN' 'NEBIVOLOL' 'ILOPERIDONE'
#  'DROSPIRENONE' 'PRASUGREL' 'ZOLPIDEM' 'RALOXIFENE' 'OLMESARTAN'
#  'ESZOPICLONE' 'CARBIDOPA' 'GLIPIZIDE' 'STAVUDINE (D4T)' 'RITONAVIR'
#  'NEVIRAPINE' 'REPAGLINIDE' 'TELMISARTAN' 'EXEMESTANE' 'TIOTROPIUM'
#  'ALBUTEROL' 'DEXTROAMPHETAMINE' 'SALMETEROL' 'TACROLIMUS' 'ABACAVIR'
#  'BOCEPREVIR' 'CARISOPRODOL' 'CEVIMELINE' 'CHLOROQUINE' 'CHLORPROPAMIDE'
#  'CLOBAZAM' 'UNKNOWN DRUG' 'DAPSONE' 'DEXLANSOPRAZOLE' 'DEXTROMETHORPHAN'
#  'DOXEPIN' 'ELTROMBOPAG' 'FLURBIPROFEN' 'GALANTAMINE' 'INDACATEROL'
#  'MAFENIDE' 'METOCLOPRAMIDE' 'MODAFINIL' 'MYCOPHENOLIC ACID'
#  'NALIDIXIC ACID' 'NEFAZODONE' 'NILOTINIB' 'NITROFURANTOIN' 'PAZOPANIB'
#  'ELECTROLYTES/PEG-3350' 'PEGINTERFERON ALFA-2B' 'PEGLOTICASE' 'PIMOZIDE'
#  'PRIMAQUINE' 'PROPAFENONE' 'PROTRIPTYLINE' 'QUINIDINE' 'QUININE SULFATE'
#  'RASBURICASE' 'SODIUM NITRITE' 'SUCCIMER' 'TERBINAFINE' 'TETRABENAZINE'
#  'THIOGUANINE' 'THIORIDAZINE' 'TICAGRELOR' 'TOLTERODINE' 'TRIMIPRAMINE'
#  'VORICONAZOLE']
#          NDF-RT     SNOMED ndfrt_preferred_label  \
# 38  N0000006993   25064002             IBUPROFEN
# 39  N0000006993   37796009             IBUPROFEN
# 40  N0000006993   65754002             IBUPROFEN
# 41  N0000006993   69896004             IBUPROFEN
# 42  N0000006993   83330001             IBUPROFEN
# 43  N0000006993   90560007             IBUPROFEN
# 44  N0000006993  128139000             IBUPROFEN
# 45  N0000006993  190905008             IBUPROFEN
# 46  N0000006993  386661006             IBUPROFEN
# 47  N0000006993  396275006             IBUPROFEN
# 48  N0000007444   15628003           MINOCYCLINE
# 49  N0000007444   23511006           MINOCYCLINE
# 50  N0000007444   29227009           MINOCYCLINE
#
#                       snomed_disease
# 38                          Headache
# 39                          Migraine
# 40              Primary dysmenorrhea
# 41              Rheumatoid arthritis
# 42          Patent ductus arteriosus
# 43                              Gout
# 44             Inflammatory disorder
# 45                   Cystic fibrosis
# 46                   Fever (finding)
# 47         Osteoarthritis (disorder)
# 48                         Gonorrhea
# 49  Meningococcal infectious disease
# 50                       Nocardiosis

# %%
#building correspondence
claim2canon = (
    DGIDB.dropna(subset=["drug_claim_name", "drug_name"])
         .drop_duplicates("drug_claim_name")
         .set_index("drug_claim_name")["drug_name"]
         .to_dict()
)

DDDB["ndfrt_preferred_label"] = (
    DDDB["ndfrt_preferred_label"].map(claim2canon).fillna(DDDB["ndfrt_preferred_label"])
)

# %%
#view result
DDDB.iloc[38:51]
# Out:
#          NDF-RT     SNOMED   ndfrt_preferred_label  \
# 38  N0000006993   25064002  IBUPROFEN, SODIUM SALT
# 39  N0000006993   37796009  IBUPROFEN, SODIUM SALT
# 40  N0000006993   65754002  IBUPROFEN, SODIUM SALT
# 41  N0000006993   69896004  IBUPROFEN, SODIUM SALT
# 42  N0000006993   83330001  IBUPROFEN, SODIUM SALT
# 43  N0000006993   90560007  IBUPROFEN, SODIUM SALT
# 44  N0000006993  128139000  IBUPROFEN, SODIUM SALT
# 45  N0000006993  190905008  IBUPROFEN, SODIUM SALT
# 46  N0000006993  386661006  IBUPROFEN, SODIUM SALT
# 47  N0000006993  396275006  IBUPROFEN, SODIUM SALT
# 48  N0000007444   15628003             MINOCYCLINE
# 49  N0000007444   23511006             MINOCYCLINE
# 50  N0000007444   29227009             MINOCYCLINE
#
#                       snomed_disease
# 38                          Headache
# 39                          Migraine
# 40              Primary dysmenorrhea
# 41              Rheumatoid arthritis
# 42          Patent ductus arteriosus
# 43                              Gout
# 44             Inflammatory disorder
# 45                   Cystic fibrosis
# 46                   Fever (finding)
# 47         Osteoarthritis (disorder)
# 48                         Gonorrhea
# 49  Meningococcal infectious disease
# 50                       Nocardiosis

# %%
#view missing drug names

# Normalize to lowercase for fair comparison
DGIDB_names = set(DGIDB['drug_name'].str.lower())

# Filter DDDB to keep only the "missing" ones
missing_rows = DDDB[~DDDB['ndfrt_preferred_label'].str.lower().isin(DGIDB_names)]

# Show them
missing_unique = (
    missing_rows['ndfrt_preferred_label']
    .drop_duplicates()
    .sort_values()
)
print(missing_unique.to_string(index=False))
# Out:
#                   CHLORIDE (AS POTASSIUM)
#                                COLESTIPOL
#                     ELECTROLYTES/PEG-3350
#                      ESTROGENS,CONJUGATED
#                  INSULIN,ASPART PROTAMINE
#                     INSULIN,DETEMIR,HUMAN
#               INSULIN,GLARGINE,HUMAN/RDNA
#                 INSULIN,LISPRO,HUMAN/RDNA
# OMEGA-3-ACID ETHYL ESTERS 1000MG CAP,ORAL
#                                 SEVELAMER
#                           STAVUDINE (D4T)
#                              UNKNOWN DRUG

# %%
#create the updated DDDB tsv file
DDDB.to_csv(OUTPUT_PATH, sep="\t", index=False)
