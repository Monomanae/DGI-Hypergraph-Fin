# %%
import pandas as pd
DISEASE = "bipolar disorder"  # Example disease name

# %%
open_targets = pd.read_csv("../Data/openTargets.tsv", sep="\t")
print(len(open_targets))
# Out:
# 2842003

# %%
disease_related_genes_df = open_targets[open_targets["diseaseCommonName"] == DISEASE]
disease_related_genes_df = disease_related_genes_df.sort_values(by="score", ascending=False)
print("Number of related genes:",len(disease_related_genes_df))
disease_related_genes_df.head(10)
# Out:
# Number of related genes: 2864
#              diseaseId         targetId     score  evidenceCount  \
# 1632258  MONDO_0004985  ENSG00000136531  0.727275            152
# 1632544  MONDO_0004985  ENSG00000149295  0.685297            674
# 1631311  MONDO_0004985  ENSG00000082701  0.625937            253
# 1631513  MONDO_0004985  ENSG00000102468  0.613610            620
# 1632498  MONDO_0004985  ENSG00000147246  0.611434            489
# 1632592  MONDO_0004985  ENSG00000151577  0.609894            173
# 1631216  MONDO_0004985  ENSG00000069696  0.608982            158
# 1633519  MONDO_0004985  ENSG00000196876  0.607630            148
# 1631746  MONDO_0004985  ENSG00000112294  0.607372            264
# 1632171  MONDO_0004985  ENSG00000133731  0.607121            114
#
#         diseaseCommonName geneCommonName
# 1632258  bipolar disorder          SCN2A
# 1632544  bipolar disorder           DRD2
# 1631311  bipolar disorder          GSK3B
# 1631513  bipolar disorder          HTR2A
# 1632498  bipolar disorder          HTR2C
# 1632592  bipolar disorder           DRD3
# 1631216  bipolar disorder           DRD4
# 1633519  bipolar disorder          SCN8A
# 1631746  bipolar disorder        ALDH5A1
# 1632171  bipolar disorder          IMPA1
